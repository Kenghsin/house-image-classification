# %% [markdown]
# # Problem statement
#
# When I receive real estate listing notification from my realtor, I probability look at some basic information such as price, house pictures, bedrooms, bathrooms..., etc. Except price, the first impression of a house is more important than other information. If I look at house pictures then I don't like it, it doesn't matter many bedrooms, bathrooms...etc, the house have.
#
# As show in figure, the strategy of my realtor is to sending me all the houses with price under some threshold, then let me check if there any houses I like. As you can see, it is a lot of houses ot check.
#
# <img src="https://github.com/Kenghsin/house-image-classification/blob/master/assets/strategy1.png" width="619" height="123" /><br>
#
# Then, he sometimes sends me message "*there is a house you might be interested in, we can go checking it on sunday*". **How does my realtor know I probably like this house?** It might because we do house hunting for two years together, so he learned. According to this situation, can I use mechine learning algorithm to build a image classification system to classify the house images which I might like, like my realtor do? My strategy is shown in figure.
#
# <img src="https://github.com/Kenghsin/house-image-classification/blob/master/assets/strategy2.png" width="678" height="121" /><br>
#
# If this system works, I only need to check the houses which filter by system. It can svae me a lot of time.
#
# ### The main challenge of this problem would be:
#
# 1. **Insufficient data**: it doesn't make sense to ask someone watch more than 300 images.
# 2. **Image quailty**: every home owner takes pictures in different angle, different layout.
#
# # Problem solving prcoess
#
# In this project, here are seven steps for problem solving process:
#
# ### 1. Gather data:
# - Scrap data of sold houses in city of EL CERRITO, EL SOBRANTE, HERCULES, PINOLE, SAN PABLO
# - The scraped data includes house images, number of bedroom, number of bathroom, house size, lot size, price, city name.
# - Save file to city_sold.csv, such as `pinole_sold.csv`
#
# Please check `1 web-scraping.jpynb`
#
# ### 2. Data cleaning:
# - Clean each data then save file to city_sold_clean.csv such as `pinole_sold_clean.csv`
# - Merge data of five cities to `sold_clean.csv`
#
# Please check `2 data-cleaning.jpynb`
#
#
# ### 3. Image preprocessing:
#
# Separately images to three categories, can not use, like, and unlike.
#
# The width/height ratios of most images are shown in figure. Majority of width/height ratios are around 1.5.
#
# <img src="https://github.com/Kenghsin/house-image-classification/blob/master/assets/w/h_ratio_all.png" width="1052" height="279" /><br>
#
# The statistic of image size are shown in figure, the smallest height of iamges is 105. According to the majority of width/height ratios and smallest height of images, all images are resized to 150 * 100
#
# <img src="https://github.com/Kenghsin/house-image-classification/blob/master/assets/eda_images.png" width="528" height="140" /><br>
#
# - Manually remove images which is not clear or not a house imge
# - Manually label image to `like` and `unlike`
# - Remove image which the width/height ratio is not between 1 and 2
# - Resize pixel of image to 150 * 100
# - Convert image to pixel
# - Merge house features and image pixel
# - Svae file to city150X100.csv, such as `pinole150X100.csv`
#
# Please check `3 image-preprocessing.jpynb`
#
# ### 4. EDA:
#
#
# Please check `4 eda.jpynb`
#
# ### 5. Model:
# - Logistic Six classification models which is regression, decision tree, random forest, KNN, SVM, and gradient boosting are used to classify this binary class like and unlike.
#
# Please check `5 model-classification`.
#
# - A CNN model is built to classify this binary class like and unlike.
#
# Please check `5 model-cnn`
#
# ### 6. Evaluate model:
#
#
# ### 7. Answer the problem:
# - The precision is 83.8%. For every 100 listings, the improvement is 16%.
# - It is still a very interesting problem to have worked on to show the limitations of CNN technology

# %% [markdown]
# Everything looks like very good work. While it is unfortunate that you were not able to prove that this task can be done, I think it is still a very interesting problem to have worked on to show the limitations of CNN technology, and the requirements that you might constrain future work to. Make sure to reference this in your technical write and please check in with me once it is properly formatted and pushed to github.
